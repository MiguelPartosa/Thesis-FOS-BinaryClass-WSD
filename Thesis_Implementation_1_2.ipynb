# %% [markdown]
# # Dataset Transformation

# %% [markdown]
# ## TODO for 50%
#   - [ ] Import dataset with pandas
#   - [ ] Run CEBPOS tags on column 2 and filter
#   - [ ] Transform per row example in column 28 into multiple rows
#   - [ ] Use gpt to generate literal examples and find literal example from seperate dataset
#   - [ ] Show innacurate/hallucinated generated from gpt examples and remove from rows
#
# ## Maybe included ?
#   - [ ] Train Test split

# %% [markdown]
# # CEB POS Tagging

# %% [markdown]
# ### Setup

# %%
# !git clone https://github.com/MiguelPartosa/Thesis-FOS-BinaryClass-WSD.git
# %cd Thesis-FOS-BinaryClass-WSD/
# %cd Cebuano_POS_Tagger/
# !pip install -r requirements.txt
import nltk
nltk.download('punkt_tab')
# Out:
# Cloning into 'Thesis-FOS-BinaryClass-WSD'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 133 (delta 39), reused 117 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 16.49 MiB | 18.25 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# /content/Thesis-FOS-BinaryClass-WSD/Cebuano_POS_Tagger/Thesis-FOS-BinaryClass-WSD
# /content/Thesis-FOS-BinaryClass-WSD/Cebuano_POS_Tagger/Thesis-FOS-BinaryClass-WSD/Cebuano_POS_Tagger
# Collecting backports-abc==0.5 (from -r requirements.txt (line 1))
#   Using cached backports_abc-0.5-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting backports.shutil-get-terminal-size==1.0.0 (from -r requirements.txt (line 2))
#   Using cached backports.shutil_get_terminal_size-1.0.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting backports.shutil-which==3.5.1 (from -r requirements.txt (line 3))
#   Using cached backports.shutil_which-3.5.1-py2.py3-none-any.whl.metadata (769 bytes)
# Collecting bleach==2.1.3 (from -r requirements.txt (line 4))
#   Using cached bleach-2.1.3-py2.py3-none-any.whl.metadata (15 kB)
# Collecting colorama==0.3.9 (from -r requirements.txt (line 5))
#   Using cached colorama-0.3.9-py2.py3-none-any.whl.metadata (13 kB)
# Collecting configparser==3.5.0 (from -r requirements.txt (line 6))
#   Using cached configparser-3.5.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting decorator==4.3.0 (from -r requirements.txt (line 7))
#   Using cached decorator-4.3.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting entrypoints==0.2.3 (from -r requirements.txt (line 8))
#   Using cached entrypoints-0.2.3-py2.py3-none-any.whl.metadata (382 bytes)
# Collecting enum34==1.1.6 (from -r requirements.txt (line 9))
#   Using cached enum34-1.1.6-py3-none-any.whl.metadata (1.7 kB)
# ERROR: Ignored the following yanked versions: 3.1.0, 3.1.1
# ERROR: Ignored the following versions that require a different python version: 3.1.1.post1 Requires-Python >=2.6, <3; 3.2.0 Requires-Python >=2.6, <3; 3.3.0 Requires-Python >=2.6, <3; 3.4.0 Requires-Python >=2.6, <3
# ERROR: Could not find a version that satisfies the requirement futures==3.2.0 (from versions: 0.1, 0.2, 1.0, 2.0, 2.1, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.2.0, 3.0.0, 3.0.1, 3.0.2, 3.0.3, 3.0.4, 3.0.5)
# ERROR: No matching distribution found for futures==3.2.0
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### Test

# %%
from cebpostagger.tagger import tag_sentence

print(tag_sentence('Ang bata naligo sa sapa.'))
print(tag_sentence('Ganahan kog prutas.'))
# Out:
# [(b'Ang', 'DET'), (b'bata', 'NOUN'), (b'naligo', 'VERB'), (b'sa', 'PART'), (b'sapa', 'NOUN'), (b'.', 'SYM')]
# [(b'Ganahan', 'VERB'), (b'kog', 'PRON'), (b'prutas', 'NOUN'), (b'.', 'SYM')]
